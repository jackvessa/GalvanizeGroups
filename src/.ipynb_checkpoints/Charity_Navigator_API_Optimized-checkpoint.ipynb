# %%
# Imports
import json
from pandas.io.json import json_normalize
import requests
import pyspark as ps
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
from textwrap import wrap
import folium
import plotly.graph_objects as go
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
# Methods
def unpack_column(dataFrame,col_name):
    newDf = dataFrame.from_records(dataFrame[col_name].dropna().tolist())
    return newDf

def unpack_and_destroy(dataFrame,column):
    temp = unpack_column(dataFrame,column)
    for col in temp.columns:
        dataFrame[col] = temp[col]
    #dataFrame = dataFrame.drop(columns=[column])
    return dataFrame

def sort_db_value(db,value,asc=False):
    return db.sort_values(by = value, ascending = asc)

def freq_array(freq_list):
    freq = []
    for i in freq_list:
        freq.append(i)
    return freq

def set_labels(freq, ax,horz_shift=.2,vert_shift=1000,w="bold",fsize=10,c="b"):
    for i, v in enumerate(freq):
        ax.text(i-horz_shift,v+vert_shift, str(round(v,2)), weight = w,fontsize=fsize,color = c)
        
def wrap_axis_labels(labels_list,wrap_length=13):
    labels_list = [ '\n'.join(wrap(l, wrap_length)) for l in labels_list]
    return labels_list

# %%
# API_url = "https://api.data.charitynavigator.org/v2/Organizations?app_id=4239274b&app_key=c78b1e5cf16a02eaf43992fbb60ce979&pageSize=1000&pageNum=1&rated=true&sort=RATING%3ADESC"
# API_dataFrame = pd.read_json(API_url)

# %%
# #Unpacking the Dictionaries
# for col in API_dataFrame:
#     if type(API_dataFrame[col][0]) == dict:
#         unpack_and_destroy(API_dataFrame,col)

# %%
# API_dataFrame.head()
# Out:
#                                           advisories  \
# 0  {'severity': None, 'active': {'_rapid_links': ...
# 1  {'severity': None, 'active': {'_rapid_links': ...
# 2  {'severity': None, 'active': {'_rapid_links': ...
# 3  {'severity': None, 'active': {'_rapid_links': ...
# 4  {'severity': None, 'active': {'_rapid_links': ...
#
#                                             category  \
# 0  {'categoryName': 'Health', 'categoryID': 5, 'c...
# 1  {'categoryName': 'International', 'categoryID'...
# 2  {'categoryName': 'Animals', 'categoryID': 1, '...
# 3  {'categoryName': 'Environment', 'categoryID': ...
# 4  {'categoryName': 'Community Development', 'cat...
#
#                                                cause  \
# 0  {'causeID': 13, 'causeName': 'Diseases, Disord...
# 1  {'causeID': 20, 'causeName': 'Development and ...
# 2  {'causeID': 2, 'causeName': 'Animal Rights, We...
# 3  {'causeID': 11, 'causeName': 'Environmental Pr...
# 4  {'causeID': 42, 'causeName': 'United Ways', 'c...
#
#                                  charityName  \
# 0           Florida Breast Cancer Foundation
# 1                  Haitian Health Foundation
# 2                        SPCA of Westchester
# 3  Conservation Foundation of the Gulf Coast
# 4                United Way of Blount County
#
#                                  charityNavigatorURL  \
# 0  https://www.charitynavigator.org/?bay=search.s...
# 1  https://www.charitynavigator.org/?bay=search.s...
# 2  https://www.charitynavigator.org/?bay=search.s...
# 3  https://www.charitynavigator.org/?bay=search.s...
# 4  https://www.charitynavigator.org/?bay=search.s...
#
#                                        currentRating donationAddress  \
# 0  {'ratingImage': {'small': 'https://d20umu42aun...             NaN
# 1  {'ratingImage': {'small': 'https://d20umu42aun...             NaN
# 2  {'ratingImage': {'small': 'https://d20umu42aun...             NaN
# 3  {'ratingImage': {'small': 'https://d20umu42aun...             NaN
# 4  {'ratingImage': {'small': 'https://d20umu42aun...             NaN
#
#          ein                                  irsClassification  \
# 0  010694045  {'deductibility': 'Contributions are deductibl...
# 1  061135999  {'deductibility': 'Contributions are deductibl...
# 2  131740069  {'deductibility': 'Contributions are deductibl...
# 3  200345249  {'deductibility': 'Contributions are deductibl...
# 4  237122193  {'deductibility': 'Contributions are deductibl...
#
#                                       mailingAddress  ...  \
# 0  {'country': None, 'stateOrProvince': 'FL', 'ci...  ...
# 1  {'country': None, 'stateOrProvince': 'CT', 'ci...  ...
# 2  {'country': None, 'stateOrProvince': 'NY', 'ci...  ...
# 3  {'country': None, 'stateOrProvince': 'FL', 'ci...  ...
# 4  {'country': None, 'stateOrProvince': 'TN', 'ci...  ...
#
#                                             nteeType      rulingDate  \
# 0                                   Medical Research     April, 2003
# 1  International, Foreign Affairs and National Se...  December, 1985
# 2                                     Animal-Related  December, 1959
# 3  Environmental Quality, Protection and Beautifi...  December, 2003
# 4  Philanthropy, Voluntarism and Grantmaking Foun...    August, 1971
#
#   subsection              city country postalCode  stateOrProvince  \
# 0  501(c)(3)       North Miami    None      33181               FL
# 1  501(c)(3)           Norwich    None      06360               CT
# 2  501(c)(3)  Briarcliff Manor    None      10510               NY
# 3  501(c)(3)            Osprey    None      34229               FL
# 4  501(c)(3)         Maryville    None      37804               TN
#
#              streetAddress1       streetAddress2  \
# 0  11900 Biscayne Boulevard            Suite 288
# 1         97 Sherman Street                 None
# 2      590 North State Road                 None
# 3              P.O. Box 902  400 Palmetto Avenue
# 4   1615 E. Broadway Avenue                 None
#
#                                         _rapid_links
# 0  {'related': {'href': 'https://api.data.charity...
# 1  {'related': {'href': 'https://api.data.charity...
# 2  {'related': {'href': 'https://api.data.charity...
# 3  {'related': {'href': 'https://api.data.charity...
# 4  {'related': {'href': 'https://api.data.charity...
#
# [5 rows x 51 columns]

# %%
# #Drop Columns (31)
# # API_dataFrame = API_dataFrame.drop(columns=['advisories','category','cause', 'charityNavigatorURL', 'currentRating'])
# # API_dataFrame = API_dataFrame.drop(columns=['donationAddress','irsClassification','mailingAddress', 'organization', 'websiteURL'])
# # API_dataFrame = API_dataFrame.drop(columns=['active','severity','image', 'rulingDate', 'subsection'])
# # API_dataFrame = API_dataFrame.drop(columns=['ratingImage','nteeLetter','nteeSuffix', 'streetAddress2', '_rapid_links'])
# # API_dataFrame = API_dataFrame.drop(columns=['accountingPeriod','latest990','nteeCode', 'country'])
# # API_dataFrame = API_dataFrame.drop(columns=['affiliation','filingRequirement','groupName', 'foundationStatus'])
# # API_dataFrame = API_dataFrame.drop(columns=['deductibilityDetail','exemptOrgStatus','exemptOrgStatusCode'])

# API_dataFrame.sort_values(by='rating',ascending=False).head(50)
# Out:
#                                            charityName        ein  \
# 0                     Florida Breast Cancer Foundation  010694045
# 648                                  Samaritan's Purse  581437002
# 650  Conquer Cancer Foundation of the American Soci...  311667995
# 651                   United Way of Southwest Michigan  381358411
# 652                                 Boca Helping Hands  311713631
# 653                                            buildOn  223128648
# 632  Transforming lung cancer into a chronically ma...           5
# 633    Restoring and preserving our marine environment           1
# 634  The St. Boniface Haiti Foundation is dedicated...           7
# 635       Sharing Christ's Love By Meeting Human Needs           6
#
#                   categoryName  causeID  \
# 0                       Health       13
# 648              International       20
# 650                     Health       14
# 651      Community Development       42
# 652             Human Services       29
# 653              International       20
# 654             Human Services       28
# 655      Community Development       27
# 656     Human and Civil Rights       21
# 657  Arts, Culture, Humanities        4
# 658              International       19
# 659      Community Development       42
# 660                Environment       11
# 661  Arts, Culture, Humanities        3
# 662             Human Services       17
# 663                    Animals       32
# 664  Arts, Culture, Humanities        4
# 665              International       20
# 666                     Health       34
# 667  Arts, Culture, Humanities        3
# 668                     Health       12
# 669                    Animals        2
# 670                Environment       11
# 671             Human Services       18
# 672      Community Development       27
# 673     Human and Civil Rights       21
# 674             Human Services       29
# 675              International       19
# 676                  Education       40
# 649                     Health       14
# 647      Community Development       42
# 678                    Animals        2
# 646      Community Development       43
# 619             Human Services       29
# 620                    Animals        2
# 621             Human Services       29
# 622             Human Services       17
# 623                     Health       14
# 624      Community Development       42
# 625  Arts, Culture, Humanities        3
# 626                   Religion       25
# 627             Human Services       29
# 628              International       20
# 629             Human Services       29
# 630  Arts, Culture, Humanities        5
# 631                Environment       11
# 632                     Health       13
# 633                    Animals       32
# 634              International       20
# 635             Human Services       29
#
#                                             causeName  rating   assetAmount  \
# 0                Diseases, Disorders, and Disciplines     4.0  2.221944e+06
# 648                   Development and Relief Services     4.0  6.782103e+08
# 650                                  Medical Research     4.0  6.943405e+07
# 651                                       United Ways     4.0  8.118257e+06
# 652                                   Social Services     4.0  6.761700e+06
# 653                   Development and Relief Services     4.0  1.358512e+07
# 654                                 Homeless Services     4.0  5.267610e+06
# 655              Housing and Neighborhood Development     4.0  5.586265e+06
# 656                            Advocacy and Education     4.0  9.351053e+06
# 657                                   Performing Arts     4.0  3.668778e+07
# 658        International Peace, Security, and Affairs     4.0  8.612013e+06
# 659                                       United Ways     4.0  8.517279e+06
# 660         Environmental Protection and Conservation     4.0  9.610957e+06
# 661                                           Museums     4.0  4.364353e+09
# 662                    Children's and Family Services     4.0  3.743282e+06
# 663                                Zoos and Aquariums     4.0  4.749662e+08
# 664                                   Performing Arts     4.0  2.907550e+06
# 665                   Development and Relief Services     4.0  1.805368e+07
# 666                        Patient and Family Support     4.0  2.297241e+07
# 667                                           Museums     4.0  7.377151e+07
# 668                 Treatment and Prevention Services     4.0  1.029522e+07
# 669              Animal Rights, Welfare, and Services     4.0  3.944375e+07
# 670         Environmental Protection and Conservation     4.0  2.766944e+06
# 671  Food Banks, Food Pantries, and Food Distribution     4.0  1.100715e+07
# 672              Housing and Neighborhood Development     4.0  3.013590e+06
# 673                            Advocacy and Education     4.0  9.619974e+06
# 674                                   Social Services     4.0  6.200271e+06
# 675        International Peace, Security, and Affairs     4.0  1.539904e+06
# 676             Youth Education Programs and Services     4.0  1.262617e+07
# 649                                  Medical Research     4.0  5.171798e+06
# 647                                       United Ways     4.0  1.948097e+06
# 633                    Educational Organization  Contributions are deductible
# 634                      Religious Organization  Contributions are deductible
# 635                     Charitable Organization  Contributions are deductible
#
#     deductibilityCode  incomeAmount  \
# 0                   1  1.662411e+06
# 648                 1  8.854806e+08
# 650                 1  4.403910e+07
# 651                 1  6.150225e+06
# 652                 1  6.764049e+06
# 653                 1  2.400419e+07
# 654                 1  1.849329e+06
# 655                 1  2.803760e+06
# 656                 1  1.592475e+07
# 657                 1  1.409025e+07
# 658                 1  6.295933e+06
# 659                 1  4.163828e+06
# 660                 1  6.771766e+06
# 661                 1  1.210558e+09
# 662                 1  4.142822e+06
# 663                 1  1.676151e+08
# 664                 1  2.627204e+06
# 665                 1  5.493455e+06
# 666                 1  4.694795e+06
# 667                 1  3.204049e+07
# 668                 1  9.378952e+06
# 669                 1  3.401410e+07
# 670                 1  3.350685e+06
# 671                 1  2.789097e+07
# 672                 1  3.319166e+06
# 673                 1  1.138537e+07
# 674                 1  6.122185e+06
# 675                 1  1.621138e+06
# 676                 1  3.465324e+06
# 649                 1  2.484695e+06
# 647                 1  8.422000e+05
# 678                 1  5.114936e+06
# 646                 1  7.261248e+06
# 619                 1  1.018945e+07
# 620                 1  3.889224e+06
# 621                 1  7.175297e+07
# 622                 1  3.111466e+06
# 623                 1  7.596788e+06
# 624                 1  1.337398e+06
# 625                 1  7.338257e+07
# 626                 1  2.142263e+07
# 627                 1  3.741962e+06
# 628                 1  5.512075e+07
# 629                 1  6.285779e+07
# 630                 1  3.240622e+08
# 631                 1  3.490426e+07
# 632                 1  4.890012e+06
# 633                 1  3.960608e+07
# 634                 1  1.108586e+07
# 635                 1  8.303789e+06
#
#                                     nteeClassification  \
# 0               Fund Raising and/or Fund Distribution
# 648                                          Christian
# 650                       Single Organization Support
# 651   Fund Raising Organizations That Cross Categories
# 652                                   Congregate Meals
# 653         International Development, Relief Services
# 654           Pollution Abatement and Control Services
# 655                                               None
# 656                   Alliance/Advocacy Organizations
# 657                                Symphony Orchestras
# 658                         International Human Rights
# 659   Fund Raising Organizations That Cross Categories
# 660      Natural Resources Conservation and Protection
# 661                                        Art Museums
# 662            Neighborhood Centers, Settlement Houses
# 663                       Single Organization Support
# 664                                               None
# 665         International Development, Relief Services
# 666                                 Public Foundations
# 667                     Science and Technology Museums
# 668         Ambulatory Health Center, Community Clinic
# 669                      Animal Protection and Welfare
# 670      Natural Resources Conservation and Protection
# 671                          Food Banks, Food Pantries
# 672                         Cultural, Ethnic Awareness
# 673                                     Legal Services
# 674                                               None
# 675                        Residential, Custodial Care
# 676         Human Service Organizations - Multipurpose
# 649                           Brain Disorders Research
# 647                                               None
# 678                      Animal Protection and Welfare
# 646   Fund Raising Organizations That Cross Categories
# 619         Health - General and Rehabilitative N.E.C.
# 620                                               None
# 621         Human Service Organizations - Multipurpose
# 622         Civil Rights, Advocacy for Specific Groups
# 623                                               None
# 624   Fund Raising Organizations That Cross Categories
# 625                                        Art Museums
# 626                                          Christian
# 627      Food Service, Free Food Distribution Programs
# 628          Disaster Preparedness and Relief Services
# 629        Emergency Assistance (Food, Clothing, Cash)
# 658      10001              NY                  121 West 27th Street
# 659      62704              IL                    1999 Wabash Avenue
# 660      97210              OR           5151 Northwest Cornell Road
# 661      10028              NY                     1000 Fifth Avenue
# 662      77009              TX                       1410 Lee Street
# 663  93940                  CA                       886 Cannery Row
# 664      10018              NY                        520 8th Avenue
# 665      10018              NY                         1430 Broadway
# 666      32240              FL                        P.O. Box 50798
# 667  95113                  CA               201 South Market Street
# 668      84101              UT                    409 West 400 South
# 669      75212              TX                  2400 Lone Star Drive
# 670      59771              MT                          P.O. Box 157
# 671      05641              VT                        33 Parker Road
# 672      94060              CA                          P.O. Box 554
# 673      10001              NY                  151 West 30th Street
# 674      37209              TN                   5122 Charlotte Pike
# 675      06820              CT                  25 Old Kings Highway
# 676      34116              FL                   4300 21st Avenue SW
# 649      60601              IL                 One East Wacker Drive
# 647      36535              AL             700 North McKenzie Street
# 678      33433              FL                   21287 Boca Rio Road
# 646      95032              CA                        14855 Oka Road
# 619      10018              NY                         1350 Broadway
# 620      97502              OR                    10175 Wheeler Road
# 621      55403              MN              1200 Second Avenue South
# 622      40223              KY      10200 Linn Station Rd, Suite 310
# 623      30338              GA              200 Ashford Center North
# 624      08822              NJ         4 Walter East Foran Boulevard
# 625  40208                  KY               2035 South Third Street
# 626      87107              NM                   2421 Aztec Road, NE
# 627      92058              CA                3260 Production Avenue
# 628      90045              CA  6171 W. Century Boulevard, Suite 310
# 629      57718              SD                      12085 Quaal Road
# 630      02135              MA                      One Guest Street
# 631      02129              MA                        10 City Square
# 632      94070              CA                  1100 Industrial Road
# 633      33767              FL                  249 Windward Passage
# 634      02459              MA                           40 Glen Ave
# 635      17019              PA                       99 W. Church St

# %%
# API_dataFrame.shape
# Out:
# (1000, 20)

# %%
# API_dataFrame.hist()
# plt.tight_layout()

# %%
# API_dataFrame.groupby('categoryName').size()
# Out:
# categoryName
# Animals                        66
# Arts, Culture, Humanities      52
# Community Development         156
# Education                      69
# Environment                    62
# Health                        114
# Human Services                290
# Human and Civil Rights         43
# International                 109
# Religion                       26
# Research and Public Policy     13
# dtype: int64

# %%
Four_Star_Charities = API_dataFrame[API_dataFrame['rating'] == 4.0]
Four_Star_Charities.shape
# Out:
# (982, 20)

# %%
# Charity Count Bar Graph 1
category_count = Four_Star_Charities.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+18,30)) ;
ax.set_title("Four-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
# mask = API_dataFrame[API_dataFrame["city"]=="Miami"]

# %%
# mask
# Out:
#                                            charityName        ein  \
# 202  Miami Lighthouse for the Blind and Visually Im...  590637847
# 271                     American Nicaraguan Foundation  650326517
# 334                    Greater Miami Jewish Federation  590624404
# 368                                Chapman Partnership  650425069
#
#                                                mission  \
# 202  Established in 1931, Miami Lighthouse for the ...
# 271  The American Nicaraguan Foundation (ANF) was f...
# 334  Founded in 1938, the Greater Miami Jewish Fede...
# 368  Since 1995, Chapman Partnership, formerly Comm...
#
#                                                tagLine  categoryID  \
# 202        Providing hope, confidence and independence           6
# 271  Providing education, health, food and housing ...           7
# 334  Touching Jewish lives. Building Jewish community.          10
# 368                            Empowering the Homeless           6
#
#               categoryName  causeID                     causeName  rating  \
# 202         Human Services       29               Social Services     4.0
# 271          International       30  Humanitarian Relief Supplies     4.0
# 334  Community Development       43            Jewish Federations     4.0
# 368         Human Services       28             Homeless Services     4.0
#
#      assetAmount           classification                 deductibility  \
# 202   33844567.0  Charitable Organization  Contributions are deductible
# 271   27048438.0  Charitable Organization  Contributions are deductible
# 334  334094714.0  Charitable Organization  Contributions are deductible
# 368   69185042.0  Charitable Organization  Contributions are deductible
#
#     deductibilityCode  incomeAmount  \
# 202                 1    16592436.0
# 271                 1   112008723.0
# 334                 1    70890346.0
# 368                 1    18648084.0
#
#                                    nteeClassification  \
# 202        Blind/Visually Impaired Centers, Services
# 271        International Development, Relief Services
# 334  Fund Raising Organizations That Cross Categories
# 368                Homeless Persons Centers, Services
#
#                                               nteeType   city postalCode  \
# 202            Human Services - Multipurpose and Other  Miami      33130
# 271  International, Foreign Affairs and National Se...  Miami      33126
# 334  Philanthropy, Voluntarism and Grantmaking Foun...  Miami  33137
# 368            Human Services - Multipurpose and Other  Miami      33136
#
#     stateOrProvince               streetAddress1
# 202              FL  601 Southwest Eighth Avenue
# 271              FL                1000 NW 57 CT
# 334              FL      4200 Biscayne Boulevard
# 368              FL      1550 North Miami Avenue

# %%
# API_url_2 = "https://api.data.charitynavigator.org/v2/Organizations?app_id=4239274b&app_key=c78b1e5cf16a02eaf43992fbb60ce979&pageSize=1000&pageNum=2&rated=true&sort=RATING%3ADESC"
# API_dataFrame_2 = pd.read_json(API_url_2)

# %%
# #Unpacking the Dictionaries
# for col in API_dataFrame_2:
#     if type(API_dataFrame_2[col][0]) == dict:
#         unpack_and_destroy(API_dataFrame_2,col)

# %%
# #Drop Columns (31)
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['advisories','category','cause', 'charityNavigatorURL', 'currentRating'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['donationAddress','irsClassification','mailingAddress', 'organization', 'websiteURL'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['active','severity','image', 'rulingDate', 'subsection'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['ratingImage','nteeLetter','nteeSuffix', 'streetAddress2', '_rapid_links'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['accountingPeriod','latest990','nteeCode', 'country'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['affiliation','filingRequirement','groupName', 'foundationStatus'])
# # API_dataFrame_2 = API_dataFrame_2.drop(columns=['deductibilityDetail','exemptOrgStatus','exemptOrgStatusCode'])

# API_dataFrame_2.sort_values(by='rating',ascending=True).head(50)
# Out:
#                                            charityName        ein  \
# 72                                  Community Servings  223154028
# 370                    Educational Organization  Contributions are deductible
# 716                    Educational Organization  Contributions are deductible
# 614                     Charitable Organization  Contributions are deductible
# 866                     Charitable Organization  Contributions are deductible
# 663                     Charitable Organization  Contributions are deductible
# 665  Organization to Prevent Cruelty to Animals  Contributions are deductible
# 640                     Charitable Organization  Contributions are deductible
# 666                     Charitable Organization  Contributions are deductible
#
#     deductibilityCode  incomeAmount  \
# 72                  1    12153548.0
# 362                 1    22266018.0
# 540                 1    12598448.0
# 33                  1     5628572.0
# 34                  1     3809941.0
# 711                 1     7310167.0
# 472                 1    17128111.0
# 887                 1     2744800.0
# 405                 1     8199923.0
# 889                 1     2492542.0
# 608                 1     2597490.0
# 891                 1     3630865.0
# 702                 1     4627368.0
# 479                 1   101879071.0
# 461                 1     1818204.0
# 54                  1     2254089.0
# 790                 1   142916897.0
# 315                 1    24051854.0
# 103                 1     3845355.0
# 903                 1    11296715.0
# 68                  1     8031797.0
# 443                 1     1166050.0
# 94                  1     3432319.0
# 928                 1     6115624.0
# 576                 1     2082333.0
# 817                 1     6253423.0
# 330                 1     4849544.0
# 895                 1     9969808.0
# 29                  1     2098358.0
# 300                 1     1158170.0
# 853                 1     4084081.0
# 984                 1    31840589.0
# 725                 1     2708832.0
# 391                 1    17654403.0
# 844                 1    12309770.0
# 293                 1    92136519.0
# 754                 1     2862045.0
# 618                 1     5303971.0
# 863                 1    12119669.0
# 162                 1     7231813.0
# 729                 1    10596639.0
# 163                 1     2203119.0
# 370                 1    18443932.0
# 716                 1    42340406.0
# 614                 1   169974309.0
# 866                 1     2745468.0
# 663                 1     6201517.0
# 665                 1     1132988.0
# 640                 1   130732288.0
# 666                 1   125459669.0
#
#                                     nteeClassification  \
# 72   Services to Promote the Independence of Specif...
# 362                          Food Banks, Food Pantries
# 540                                            Theater
# 33              Fund Raising and/or Fund Distribution
# 34            Birth Defects, Genetic Diseases Research
# 711                       Single Organization Support
# 472                                   Religious Radio
# 887                Media, Communications Organizations
# 405  Scholarships, Student Financial Aid Services, ...
# 889                   Alliance/Advocacy Organizations
# 608  Environmental Education and Outdoor Survival P...
# 891  Botanical Gardens, Arboreta and Botanical Orga...
# 702                                               None
# 479   Fund Raising Organizations That Cross Categories
# 461  Water Resource, Wetlands Conservation and Mana...
# 54                                   Family Counseling
# 790                          Food Banks, Food Pantries
# 315   Fund Raising Organizations That Cross Categories
# 103                                               None
# 903                                               None
# 68                                                None
# 443        Environmental Beautification and Aesthetics
# 94                  Other Services - Specialty Animals
# 928        Emergency Assistance (Food, Clothing, Cash)
# 576   Fund Raising Organizations That Cross Categories
# 817   Fund Raising Organizations That Cross Categories
# 330      Natural Resources Conservation and Protection
# 895         International Development, Relief Services
# 29   Scholarships, Student Financial Aid Services, ...
# 300                                               None
# 853         Human Service Organizations - Multipurpose
# 984                                    Minority Rights
# 725                   Alliance/Advocacy Organizations
# 391                                               None
# 844                                   Computer Science
# 293                                               None
# 754                      Voter Education, Registration
# 618                       Single Organization Support
# 863       Patient Services - Entertainment, Recreation
# 162   Fund Raising Organizations That Cross Categories
# 887      94103              CA                            145 Ninth Street
# 405      90012              CA                        202 West 1st Street
# 889      43212              OH                         1145 Chesapeake Ave
# 608      48104              MI                            339 East Liberty
# 891      94122              CA                           1199 Ninth Avenue
# 702      85701              AZ                         300 North Ash Alley
# 479  85014                  AZ                    3200 East Camelback Road
# 461      48104              MI                      1100 North Main Street
# 54       32789              FL                               2100 Lee Road
# 790  30318                  GA          732 Joseph E. Lowery Boulevard, NW
# 315      97205              OR               619 Southwest Eleventh Avenue
# 103      10017              NY                             8 E 41st Street
# 903      43209              OH                         1125 College Avenue
# 68       20005              DC                           1331 G Street, NW
# 443      15601              PA                      105 West Fourth Street
# 94       91390              CA                        15825 Sierra Highway
# 928      80304              CO                        1575 Yarmouth Avenue
# 576      13502              NY                        201 Lafayette Street
# 817      32124              FL  3747 West International Speedway Boulevard
# 330      95816              CA                               2707 K Street
# 895      15222              PA                         2840 Liberty Avenue
# 29       22101              VA                      1390 Chain Bridge Road
# 300      20036              DC                           1616 P Street, NW
# 853      61652              IL                                P.O. Box 837
# 984      10006              NY                            40 Rector Street
# 725      48906              MI                          1223 Turner Street
# 391      94111              CA                       500 Washington Street
# 844      10018              NY                           520 Eighth Avenue
# 293      34108              FL                       1110 Pine Ridge Road,
# 754      27705              NC                           1821 Green Street
# 618      97232              OR                      628 Northeast Broadway
# 863      98105              WA                        5130 40th Avenue, NE
# 162      06810              CT                             301 Main Street
# 729      10001              NY                          330 Seventh Avenue
# 163      10018              NY                        315 West 39th Street
# 370  02121                  MA                      One Franklin Park Road
# 716      93108              CA                           1070 Fairway Road
# 614  85009                  AZ                      2831 North 31st Avenue
# 866      91932              CA                          925 Seacoast Drive
# 663      19802              DE                          1920 Hutton Street
# 665      72210              AR                    14600 Colonel Glenn Road
# 640  85016                  AZ                    2201 East Camelback Road
# 666      32805              FL                             411 Mercy Drive

# %%
# Four_Star_Charities_2 = API_dataFrame_2[API_dataFrame_2['rating'] == 4.0]
# Four_Star_Charities_2.shape
# Out:
# (952, 20)

# %%
# # Charity Count Bar Graph 2
# category_count = Four_Star_Charities_2.groupby('categoryName').size()
# categories = list(category_count.index.values)
# categories = wrap_axis_labels(categories,13)

# freq = freq_array(category_count)
    
# fig,ax = plt.subplots(figsize = (20,8))
# ax.bar(categories,freq, color = "b");
# ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# # Needs Adjustment based on Data
# ax.set_yticks(np.arange(0,np.max(freq)+18,30)) ;
# ax.set_title("Four-Star Charities by Category", weight = "bold",fontsize=19);
# ax.set_xlabel("Category", fontsize=15, weight = "bold");
# ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

# set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
# concat_df = pd.concat([API_dataFrame,API_dataFrame_2])

# %%
# concat_df.shape
# Out:
# (2000, 20)

# %%
# len(list(set(concat_df['ein'])))
# Out:
# 2000

# %%
# API_url_3 = "https://api.data.charitynavigator.org/v2/Organizations?app_id=4239274b&app_key=c78b1e5cf16a02eaf43992fbb60ce979&pageSize=1000&pageNum=3&rated=true&sort=RATING%3ADESC"
# API_dataFrame_3 = pd.read_json(API_url_3)
# API_dataFrame_3.shape
# Out:
# (1000, 14)

# %%
# for i in range(10,12):
#     print(1)
#     API_url = "https://api.data.charitynavigator.org/v2/Organizations?app_id=4239274b&app_key=c78b1e5cf16a02eaf43992fbb60ce979&pageSize=1000&pageNum="+str(i)+"&rated=true&sort=RATING%3ADESC"
#     API_df = pd.read_json(API_url)
#     print(2)
#     #Unpacking the Dictionaries
#     for col in API_df:
#         if type(API_df[col][0]) == dict:
#             unpack_and_destroy(API_df,col)
#     print(3)
#     #Drop Columns (31)
#     API_df = API_df.drop(columns=['advisories','category','cause', 'charityNavigatorURL', 'currentRating'])
#     API_df = API_df.drop(columns=['donationAddress','irsClassification','mailingAddress', 'organization', 'websiteURL'])
#     API_df = API_df.drop(columns=['active','severity','image', 'rulingDate', 'subsection'])
#     API_df = API_df.drop(columns=['ratingImage','nteeLetter','nteeSuffix', 'streetAddress2', '_rapid_links'])
#     API_df = API_df.drop(columns=['accountingPeriod','latest990','nteeCode', 'country'])
#     API_df = API_df.drop(columns=['affiliation','filingRequirement','groupName', 'foundationStatus'])
#     API_df = API_df.drop(columns=['deductibilityDetail','exemptOrgStatus','exemptOrgStatusCode'])
#     print(4)
#     concat_df = pd.concat([concat_df,API_df])

# %%
# concat_df.shape
# Out:
# (8646, 20)

# %%
# Charity Count Bar Graph Total
category_count = concat_df.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+200,200)) ;
ax.set_title("Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
Four_Star_Charities_Total = concat_df[concat_df['rating'] == 4.0]
Four_Star_Charities_Total.shape
# Out:
# (3440, 20)

# %%
# Charity Count Bar Graph 4-Star
category_count = Four_Star_Charities_Total.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+200,200)) ;
ax.set_title("Four-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
Three_Star_Charities_Total = concat_df[concat_df['rating'] == 3.0]
Three_Star_Charities_Total.shape
# Out:
# (3828, 20)

# %%
# Charity Count Bar Graph 3-Star
category_count = Three_Star_Charities_Total.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+100,100)) ;
ax.set_title("Three-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
Two_Star_Charities_Total = concat_df[concat_df['rating'] == 2]
Two_Star_Charities_Total.shape
# Out:
# (1054, 20)

# %%
# Charity Count Bar Graph 2-Star
category_count = Two_Star_Charities_Total.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+50,50)) ;
ax.set_title("Two-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
One_Star_Charities_Total = concat_df[concat_df['rating'] == 1]
One_Star_Charities_Total.shape
# Out:
# (248, 20)

# %%
# Charity Count Bar Graph 1-Star
category_count = One_Star_Charities_Total.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+25,25)) ;
ax.set_title("One-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
Zero_Star_Charities_Total = concat_df[concat_df['rating'] == 0]
Zero_Star_Charities_Total.shape
# Out:
# (53, 20)

# %%
# Charity Count Bar Graph 1-Star
category_count = Zero_Star_Charities_Total.groupby('categoryName').size()
categories = list(category_count.index.values)
categories = wrap_axis_labels(categories,13)

freq = freq_array(category_count)
    
fig,ax = plt.subplots(figsize = (20,8))
ax.bar(categories,freq, color = "b");
ax.set_xticklabels(categories, rotation=0, weight = "bold",fontsize=12)

# Needs Adjustment based on Data
ax.set_yticks(np.arange(0,np.max(freq)+5,5)) ;
ax.set_title("Zero-Star Charities by Category", weight = "bold",fontsize=19);
ax.set_xlabel("Category", fontsize=15, weight = "bold");
ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq,ax,.1,(np.max(freq)/100),fsize=13)

# %%
# 4 vs. 3 -Star Charities Count Bar Graph
#Four-Star
four_star_count = Four_Star_Charities_Total.groupby("categoryName").size()
categories = list(four_star_count.index.values)
categories = wrap_axis_labels(categories,13)

ind = np.arange(len(categories)) 

freq = freq_array(four_star_count)
    
fig,ax = plt.subplots(figsize = (18,10),sharex=True,sharey=True)
ax.bar(ind,freq, color = "b",width=0.35,label="Four-Star Charities");

# Needs Adjustment based on Data

ax.set_yticklabels(np.arange(0,np.max(freq)+200,100), weight="bold", fontsize =12) ;
ax.set_title("Four-Star vs. Three-Star Charities by Category", weight = "bold",fontsize=25);
ax.set_xlabel("Category", fontsize=20, weight = "bold");
ax.set_ylabel("Frequency", fontsize=20, weight = "bold");

set_labels(freq,ax,.2,(np.max(freq)/100),fsize=14,c="blue")
    
#Three-Star
three_star_count = Three_Star_Charities_Total.groupby("categoryName").size()
categories_2 = list(three_star_count.index.values)

ind_2 = np.arange(len(categories_2)) 

freq_2 = freq_array(three_star_count)
    
ax.bar(ind_2+.35,freq_2, color = "orange",width=0.35,label="Three-Star Charities");

# Needs Adjustment based on Data
# ax.set_yticks(np.arange(0,np.max(freq)+200,200)) ;
# ax.set_title("Four-Star Charities by Category", weight = "bold",fontsize=19);
# ax.set_xlabel("Category", fontsize=15, weight = "bold");
# ax.set_ylabel("Frequency", fontsize=15, weight = "bold");

set_labels(freq_2,ax,-.2,(np.max(freq)/100),fsize=14,c='black')

ax.set_yticks(np.arange(0,(np.max(freq)+100),100)) ;
ax.set_xticks(ind + .35 / 2)
ax.set_xticklabels(categories, weight="bold",fontsize=11);
ax.legend(prop={'size': 20});

# plt.savefig("Four_Star_vs_Three_Star_Categories")

# %%
API_Dataframe_CN = concat_df.copy()

# %%
API_Dataframe_CN.head()
# Out:
#                                  charityName        ein  \
# 0  Florida Breast Cancer Foundation           010694045
# 1  Haitian Health Foundation                  061135999
# 2  SPCA of Westchester                        131740069
# 3  Conservation Foundation of the Gulf Coast  200345249
# 4  United Way of Blount County                237122193
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                mission  \
# 0  Florida Breast Cancer Foundation strives to end the suffering caused by breast cancer through scientific research, community education, support resources, and public policy through advocacy.<br><br>Florida Breast Cancer Foundation funds education programs in underserved communities throughout the state in an effort to empower women and men to take control of their breast health and reduce the number of breast cancer related deaths in the state of Florida. Florida Breast Cancer Foundation is also committed to funding innovative research to discover more effective ways to diagnose, treat, and cure breast cancer.
# 1  The mission of the Haitian Health Foundation (HHF) is to improve the health and well-being of women, children, families and communities living in the greater Jérémie region through healthcare, education and community development..<br><br>This is accomplished through: a secondary care outpatient clinic; a public health outreach program; nutritional rehabilitation services; safe motherhood services; community development programs; self-help programs which advance family & community self-sufficiency; and responding to emergencies and crises with humanitarian relief.
# 2  The SPCA of Westchester was founded in 1883. Today, it is the only humane society in Westchester County empowered to enforce laws relating to animal cruelty. The SPCA's services include shelter and rehabilitation for abused, abandoned, and lost animals; adoption services; low-cost veterinary services; cruelty investigations; community outreach programs; and lost and found services. The SPCA of Westchester is located on several acres, with four separate kennel areas for dogs, a cattery and feline pavilion for cats, and the Simpson Spay/Neuter Clinic. At the present time, the Shelter is equipped to house over 100 dogs and many, many cats. Since 1983, we have spayed/neutered almost 38,000 dogs and cats thereby greatly reducing the number of unwanted animals in Westchester County.
# 3  Conservation Foundation of the Gulf Coast works to protect the character, natural integrity and biodiversity of Florida's Gulf Coast bays, beaches and barrier islands by: Holding conservation easements and owning nature preserves, educating for responsible land stewardship, collaborating with individuals, organizations and communities.
# 4  United Way of Blount County is advancing the common good by creating opportunities for a better life for all.<br>We all win when a child succeeds in school, when families are financially stable and when people have good health. That's why United Way is focused on the building blocks for a better life by supporting programs that help kids succeed, strengthen and support families, promote self-sufficiency, improve people's health, and protect community well-being. Our goal is to support programs that help the most vulnerable in Blount County.
#
#                                                   tagLine  categoryID  \
# 0  To end the suffering caused by breast cancer            5
# 1  Changing Lives ~ One Person at a Time                   7
# 2  Over 100 years of service to animals and their friends  1
# 3  Conservation through education and collaboration        4
# 4  Live united                                             10
#
#             categoryName  causeID                                  causeName  \
# 0  Health                 13       Diseases, Disorders, and Disciplines
# 1  International          20       Development and Relief Services
# 2  Animals                2        Animal Rights, Welfare, and Services
# 3  Environment            11       Environmental Protection and Conservation
# 4  Community Development  42       United Ways
#
#    rating  assetAmount           classification                 deductibility  \
# 0  4.0     2221944.0    Charitable Organization  Contributions are deductible
# 1  4.0     46434088.0   Charitable Organization  Contributions are deductible
# 2  4.0     6612191.0    Charitable Organization  Contributions are deductible
# 3  4.0     30114667.0   Charitable Organization  Contributions are deductible
# 4  4.0     4358002.0    Charitable Organization  Contributions are deductible
#
#   deductibilityCode  incomeAmount  \
# 0  1                 1662411.0
# 1  1                 15631712.0
# 2  1                 5363562.0
# 3  1                 5269608.0
# 4  1                 2279080.0
#
#                                  nteeClassification  \
# 0  Fund Raising and/or Fund Distribution
# 1  International Development, Relief Services
# 2  Animal Protection and Welfare
# 3  Natural Resources Conservation and Protection
# 4  Fund Raising Organizations That Cross Categories
#
#                                                 nteeType              city  \
# 0  Medical Research                                       North Miami
# 1  International, Foreign Affairs and National Security   Norwich
# 2  Animal-Related                                         Briarcliff Manor
# 3  Environmental Quality, Protection and Beautification   Osprey
# 4  Philanthropy, Voluntarism and Grantmaking Foundations  Maryville
#
#   postalCode stateOrProvince            streetAddress1
# 0  33181      FL              11900 Biscayne Boulevard
# 1  06360      CT              97 Sherman Street
# 2  10510      NY              590 North State Road
# 3  34229      FL              P.O. Box 902
# 4  37804      TN              1615 E. Broadway Avenue

# %%
state_df = API_Dataframe_CN.groupby("stateOrProvince").size().reset_index(name="Count")

# %%
fig = go.Figure(data=go.Choropleth(
    locations = state_df['stateOrProvince'],
    z=state_df['Count'],
    locationmode='USA-states',
    colorscale='Reds',
    autocolorscale=False,
    text=state_df['stateOrProvince'], # hover text
    marker_line_color='black', # line markers between states
    colorbar_title="Number of Charities"
))

fig.update_layout(
    title_text='Number of US Charitable Organizations by State - Rated<br>(Hover for breakdown)',
    geo = dict(
        scope='usa',
        projection=go.layout.geo.Projection(type = 'albers usa'),
        showlakes=True, # lakes
        lakecolor='rgb(255, 255, 255)'),
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a341fcd7a495> in <module>
# ----> 1 fig = go.Figure(data=go.Choropleth(
#       2     locations = state_df['stateOrProvince'],
#       3     z=state_df['Count'],
#       4     locationmode='USA-states',
#       5     colorscale='Reds',
#
# NameError: name 'go' is not defined

# %%
text = API_Dataframe_CN.mission.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'white',
    stopwords = STOPWORDS).generate(' '.join(text))
fig = plt.figure(
    figsize = (20, 15),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.savefig("Mission_Wordmap")
plt.show()

# %%
API_Dataframe_CN.tagLine.values
# Out:
# array(['To end the suffering caused by breast cancer',
#        'Changing Lives ~ One Person at a Time',
#        'Over 100 years of service to animals and their friends', ...,
#        'Working to find more effective treatments for cancer',
#        'Reduce the number of Law Enforcement officers injured and killed in the line of duty',
#        'A world of care'], dtype=object)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = API_Dataframe_CN.tagLine.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'white',
    stopwords = STOPWORDS).generate(' '.join(text))
fig = plt.figure(
    figsize = (20, 15),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()
# plt.savefig("Tagline_Wordmap")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-389-406f3601f25f> in <module>
#       6     height = 2000,
#       7     background_color = 'white',
# ----> 8     stopwords = STOPWORDS).generate(' '.join(text))
#       9 fig = plt.figure(
#      10     figsize = (20, 15),
#
# TypeError: sequence item 2320: expected str instance, NoneType found

# %%
API
